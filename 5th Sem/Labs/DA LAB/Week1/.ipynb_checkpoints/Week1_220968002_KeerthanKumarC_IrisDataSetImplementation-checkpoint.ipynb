# %% [markdown]
# # Week1 Iris Dataset Implementation

# %% [raw]
# Name: Keerthan Kumar C
# Reg no: 220968002
# Section: B
# Roll no: 2

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
import warnings
warnings.filterwarnings('ignore')
# Out:
# 2024-07-25 15:05:57.760240: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-25 15:05:57.902249: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-25 15:05:58.512994: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
columns = ['col1','col2','col3','col4','label']
df = pd.read_csv('iris.csv',names=columns)
df.head()
# Out:
#    col1  col2  col3  col4        label
# 0   5.1   3.5   1.4   0.2  Iris-setosa
# 1   4.9   3.0   1.4   0.2  Iris-setosa
# 2   4.7   3.2   1.3   0.2  Iris-setosa
# 3   4.6   3.1   1.5   0.2  Iris-setosa
# 4   5.0   3.6   1.4   0.2  Iris-setosa

# %% [markdown]
# ### Preprocessing

# %%
df.shape
# Out:
# (150, 5)

# %%
df.isnull().sum()
# Out:
# col1     0
# col2     0
# col3     0
# col4     0
# label    0
# dtype: int64

# %%
df['label'].value_counts()
# Out:
# label
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['label']=le.fit_transform(df['label'])

# %%
df['label']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: label, Length: 150, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(df)

# %% [markdown]
# ### Split the Data and scaling of Data

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.10,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
y_train
# Out:
# 56     1
# 104    2
# 69     1
# 55     1
# 132    2
#       ..
# 71     1
# 106    2
# 14     0
# 92     1
# 102    2
# Name: label, Length: 135, dtype: int64

# %% [markdown]
# ### Model Implementation

# %%
#defining the model
num_features = df.shape[1]-1
model = Sequential([
    Input(shape=(num_features,),name='input'),#the shape is (10,) to represent the vector format
    Dense(8, activation='relu',name='d1'),
    Dense(4, activation='relu',name='d2'), 
    Dense(3, activation='softmax')  
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  d1 (Dense)                  (None, 8)                 40
#
#  d2 (Dense)                  (None, 4)                 36
#
#  dense_1 (Dense)             (None, 3)                 15
#
# =================================================================
# Total params: 91 (364.00 Byte)
# Trainable params: 91 (364.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)#setting up the Learning Rate 
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
epochs = 50
batch_size = 32
model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.1)
# Out:
# Epoch 1/50
# 2024-07-25 15:16:07.762023: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x20a4c180 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-07-25 15:16:07.762053: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1660 Ti, Compute Capability 7.5
# 2024-07-25 15:16:07.791499: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-07-25 15:16:07.946417: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2024-07-25 15:16:08.067197: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 4/4 [==============================] - 2s 35ms/step - loss: 1.1431 - accuracy: 0.2479 - val_loss: 1.0685 - val_accuracy: 0.4286
# Epoch 2/50
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0623 - accuracy: 0.2810 - val_loss: 1.0247 - val_accuracy: 0.5714
# Epoch 3/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.9912 - accuracy: 0.4132 - val_loss: 0.9813 - val_accuracy: 0.5000
# Epoch 4/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8960 - accuracy: 0.5124 - val_loss: 0.9444 - val_accuracy: 0.3571
# Epoch 5/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7991 - accuracy: 0.5868 - val_loss: 0.9081 - val_accuracy: 0.2857
# Epoch 6/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7267 - accuracy: 0.5950 - val_loss: 0.8637 - val_accuracy: 0.2857
# Epoch 7/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6675 - accuracy: 0.6777 - val_loss: 0.8101 - val_accuracy: 0.6429
# Epoch 8/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6023 - accuracy: 0.7603 - val_loss: 0.7434 - val_accuracy: 0.7143
# Epoch 9/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5340 - accuracy: 0.8099 - val_loss: 0.6737 - val_accuracy: 0.6429
# Epoch 10/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4668 - accuracy: 0.8264 - val_loss: 0.6151 - val_accuracy: 0.7143
# Epoch 11/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4290 - accuracy: 0.8264 - val_loss: 0.5727 - val_accuracy: 0.7143
# Epoch 12/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3850 - accuracy: 0.8347 - val_loss: 0.5364 - val_accuracy: 0.7143
# Epoch 13/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3538 - accuracy: 0.8512 - val_loss: 0.5031 - val_accuracy: 0.7143
# Epoch 14/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3259 - accuracy: 0.8512 - val_loss: 0.4873 - val_accuracy: 0.7857
# Epoch 15/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3061 - accuracy: 0.8512 - val_loss: 0.4793 - val_accuracy: 0.8571
# Epoch 16/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2902 - accuracy: 0.8512 - val_loss: 0.4704 - val_accuracy: 0.8571
# Epoch 17/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2750 - accuracy: 0.8512 - val_loss: 0.4641 - val_accuracy: 0.8571
# Epoch 18/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2625 - accuracy: 0.8512 - val_loss: 0.4677 - val_accuracy: 0.8571
# Epoch 19/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2518 - accuracy: 0.8512 - val_loss: 0.4735 - val_accuracy: 0.8571
# Epoch 20/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2409 - accuracy: 0.8595 - val_loss: 0.4768 - val_accuracy: 0.8571
# Epoch 21/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2298 - accuracy: 0.8595 - val_loss: 0.4909 - val_accuracy: 0.9286
# Epoch 22/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2208 - accuracy: 0.8760 - val_loss: 0.4991 - val_accuracy: 0.9286
# Epoch 23/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2115 - accuracy: 0.8760 - val_loss: 0.4968 - val_accuracy: 0.9286
# Epoch 24/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2015 - accuracy: 0.8843 - val_loss: 0.4969 - val_accuracy: 0.9286
# Epoch 25/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1930 - accuracy: 0.8843 - val_loss: 0.4919 - val_accuracy: 0.9286
# Epoch 26/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1844 - accuracy: 0.9174 - val_loss: 0.4879 - val_accuracy: 0.9286
# Epoch 27/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1755 - accuracy: 0.9339 - val_loss: 0.4834 - val_accuracy: 0.9286
# Epoch 28/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1667 - accuracy: 0.9504 - val_loss: 0.4853 - val_accuracy: 0.9286
# Epoch 29/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1593 - accuracy: 0.9504 - val_loss: 0.4689 - val_accuracy: 0.9286
# Epoch 30/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1517 - accuracy: 0.9587 - val_loss: 0.4580 - val_accuracy: 0.9286
# Epoch 31/50
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1445 - accuracy: 0.9587 - val_loss: 0.4437 - val_accuracy: 0.8571
# Epoch 32/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1366 - accuracy: 0.9669 - val_loss: 0.4392 - val_accuracy: 0.9286
# Epoch 33/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1300 - accuracy: 0.9669 - val_loss: 0.4290 - val_accuracy: 0.9286
# Epoch 34/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1246 - accuracy: 0.9669 - val_loss: 0.4316 - val_accuracy: 0.9286
# Epoch 35/50
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1175 - accuracy: 0.9669 - val_loss: 0.4145 - val_accuracy: 0.9286
# Epoch 36/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1133 - accuracy: 0.9669 - val_loss: 0.4072 - val_accuracy: 0.9286
# Epoch 37/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1088 - accuracy: 0.9669 - val_loss: 0.3915 - val_accuracy: 0.9286
# Epoch 38/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1034 - accuracy: 0.9669 - val_loss: 0.3886 - val_accuracy: 0.9286
# Epoch 39/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0975 - accuracy: 0.9669 - val_loss: 0.4017 - val_accuracy: 0.9286
# Epoch 40/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0961 - accuracy: 0.9669 - val_loss: 0.4085 - val_accuracy: 0.9286
# Epoch 41/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0908 - accuracy: 0.9587 - val_loss: 0.3856 - val_accuracy: 0.9286
# Epoch 42/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0875 - accuracy: 0.9669 - val_loss: 0.3717 - val_accuracy: 0.9286
# Epoch 43/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0843 - accuracy: 0.9669 - val_loss: 0.3639 - val_accuracy: 0.9286
# Epoch 44/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0818 - accuracy: 0.9752 - val_loss: 0.3704 - val_accuracy: 0.9286
# Epoch 45/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0806 - accuracy: 0.9669 - val_loss: 0.4222 - val_accuracy: 0.9286
# Epoch 46/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0758 - accuracy: 0.9752 - val_loss: 0.4041 - val_accuracy: 0.9286
# Epoch 47/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0733 - accuracy: 0.9669 - val_loss: 0.3765 - val_accuracy: 0.9286
# Epoch 48/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0706 - accuracy: 0.9752 - val_loss: 0.3718 - val_accuracy: 0.9286
# Epoch 49/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0679 - accuracy: 0.9752 - val_loss: 0.3813 - val_accuracy: 0.9286
# Epoch 50/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0652 - accuracy: 0.9752 - val_loss: 0.4039 - val_accuracy: 0.9286

# %%
loss, accuracy = model.evaluate(X_test, y_test, batch_size=batch_size)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0743 - accuracy: 0.9333
# Test Loss: 0.07431826740503311
# Test Accuracy: 0.9333333373069763
