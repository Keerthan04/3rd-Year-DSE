# %% [raw]
# Name: Keerthan Kumar C
# Reg: 220968002
# Batch: B1
# Set: 1

# %%
import numpy as np
import pandas as pd
import random
np.random.seed(42)
random.seed(42)

# %% [markdown]
# ### Creation of our own env with arms_length as the action_space

# %%
class ENV1:
    def __init__(self,arms_length):
        #create array of 12 arms
        self.arms = [i+1 for i in range(arms_length)]
    def arms_return(self):
        return self.arms
    def reward_return(self):
        #generate a random reward between -10 and 25
        return np.random.randint(-10,26)
    def print_action(self,arm_index):
        #print the action taken
        print(f"Arm pulled is {self.arms[arm_index]} \n")

# %% [markdown]
# ### Define the epsilon greedy and ucb policy

# %%
def epsilon_greedy(Q_values,N_values,epsilon):
    if np.random.rand() < epsilon:
        return np.random.choice(len(Q_values))
    else:
        return np.argmax(Q_values)

    
def ucb(Q_values,N_values,steps,c):
    ucb_list = []
    for i in range(len(Q_values)):
        if N_values[i] == 0:
            ucb_list.append(np.inf)
        else:
            ucb_list.append(Q_values[i]+ c * (np.sqrt(2 * np.log(steps+1) / N_values[i])))
    return np.argmax(ucb_list)

# %% [markdown]
# ### Define the variables

# %%
steps=0
arms_length = 12
env = ENV1(arms_length)
Q_values = np.zeros(arms_length)
N_values = np.zeros(arms_length)
epsilon = 0.7
c = 4.2

# %% [markdown]
# ### Run the policies

# %%
def run_epsilon_policy(Q_values,N_values,epsilon,env,steps):
    print("running the epsilon greedy policy \n")
    epsilon_reward = 0
    while steps<5000:
        print(f"step: {steps+1} \n")
        action = epsilon_greedy(Q_values,N_values,epsilon)
        print(f"the action arm chosen is {action+1} \n")
        N_values[action]+=1
        env.print_action(action)
        reward = env.reward_return()
        print(f"the reward got is  {reward} \n")
        Q_values[action] +=(reward - Q_values[action]) /N_values[action]
        epsilon_reward+=reward
        steps+=1
    print("Epsilon greedy policy for 5000 steps done \n")
    return epsilon_reward

def run_ucb_policy(Q_values,N_values,c,env,steps):
    print("running the ucb policy \n")
    ucb_reward = 0
    while steps<5000:
        print(f"step: {steps+1} \n")
        action = ucb(Q_values,N_values,steps,c)
        print(f"the action arm chosen is {action+1} \n")
        N_values[action]+=1
        env.print_action(action)
        reward = env.reward_return()
        print(f"the reward got is  {reward} \n")
        Q_values[action] +=(reward - Q_values[action]) /N_values[action]
        ucb_reward+=reward
        steps+=1
    print("UCB policy for 5000 steps done \n")
    return ucb_reward

# %%
epsilon_reward = run_epsilon_policy(Q_values.copy(),N_values.copy(),epsilon,env,steps)
ucb_reward = run_ucb_policy(Q_values.copy(),N_values.copy(),c,env,steps)
# Out:
# running the epsilon greedy policy
#
# step: 1
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  -10
#
# step: 2
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  19
#
# step: 3
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  16
#
# step: 4
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  25
#
# step: 5
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  25
#
# step: 6
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  14
#
# step: 7
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  6
#
# step: 8
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  20
#
# step: 9
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  -7
#
# step: 10
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  -10
#
# step: 11
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  23
#
# step: 12
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  13
#
# step: 13
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  16
#
# step: 14
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  20
#
# step: 15
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  22
#
# step: 16
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  6
#
# step: 17
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  4
#
# step: 18
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  15
#
# step: 19
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  -2
#
# step: 20
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  11
#
# step: 21
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  7
#
# step: 22
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  7
#
# step: 23
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  16
#
# step: 24
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  2
#
# step: 25
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  14
#
# step: 26
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  21
#
# step: 27
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  0
#
# step: 28
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  -9
#
# step: 29
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  15
#
# step: 30
#
# the action arm chosen is 5
#
# Arm pulled is 5
#
# the reward got is  10
#
# step: 31
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  2
#
# step: 32
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -5
#
# step: 33
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  25
#
# step: 34
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  6
#
# step: 35
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  1
#
# step: 36
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  -2
#
# step: 37
#
# the action arm chosen is 5
#
# Arm pulled is 5
#
# the reward got is  -8
#
# step: 38
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  -2
#
# step: 39
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  21
#
# step: 40
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  22
#
# step: 41
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  0
#
# step: 42
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  0
#
# step: 43
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  -4
#
# step: 44
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  15
#
# step: 45
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  24
#
# step: 46
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  10
#
# step: 47
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  -3
#
# step: 48
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -3
#
# step: 49
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  -7
#
# step: 50
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  19
#
# step: 51
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  -6
#
# step: 52
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  -5
#
# step: 53
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  13
#
# step: 54
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  3
#
# step: 55
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  15
#
# step: 56
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  17
#
# step: 57
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  -7
#
# step: 58
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  9
#
# step: 59
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  20
#
# step: 60
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  25
#
# step: 61
#
# the action arm chosen is 5
#
# Arm pulled is 5
#
# the reward got is  -1
#
# step: 62
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  22
#
# step: 63
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  11
#
# step: 64
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  4
#
# step: 65
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  17
#
# step: 66
#
# the action arm chosen is 5
#
# Arm pulled is 5
#
# the reward got is  6
#
# step: 67
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  -7
#
# step: 68
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  14
#
# step: 69
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  -2
#
# step: 70
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -2
#
# step: 71
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  20
#
# step: 72
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  11
#
# step: 73
#
# the action arm chosen is 5
#
# Arm pulled is 5
#
# the reward got is  15
#
# step: 74
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  23
#
# step: 75
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  14
#
# step: 76
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -9
#
# step: 77
#
# the action arm chosen is 5
#
# Arm pulled is 5
#
# the reward got is  0
#
# step: 78
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  3
#
# step: 79
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  24
#
# step: 80
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -6
#
# step: 81
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  23
#
# step: 82
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  0
#
# step: 83
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  23
#
# step: 84
#
# the action arm chosen is 5
#
# Arm pulled is 5
#
# the reward got is  21
#
# step: 85
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  21
#
# step: 86
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  22
#
# step: 87
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  -2
#
# step: 88
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  19
#
# step: 89
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  12
#
# step: 90
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  12
#
# step: 91
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  12
#
# step: 92
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  12
#
# step: 93
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  8
#
# step: 94
#
# the action arm chosen is 5
#
# Arm pulled is 5
#
# the reward got is  13
#
# step: 95
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  25
#
# step: 96
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  25
#
# step: 97
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  -9
#
# step: 98
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  25
#
# step: 99
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  10
#
# step: 100
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  23
#
# step: 101
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  -10
#
# step: 102
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -6
#
# step: 103
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  -7
#
# step: 104
#
# the action arm chosen is 5
#
# Arm pulled is 5
#
# the reward got is  11
#
# step: 105
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  -7
#
# step: 106
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  6
#
# step: 107
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  -1
#
# step: 108
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  11
#
# step: 109
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  6
#
# step: 110
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  19
#
# step: 111
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  -4
#
# step: 112
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  19
#
# step: 113
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  20
#
# step: 114
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -9
#
# step: 115
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  23
#
# step: 116
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  22
#
# step: 117
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  15
#
# step: 118
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  15
#
# step: 119
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  0
#
# step: 120
#
# the action arm chosen is 5
#
# Arm pulled is 5
#
# the reward got is  -9
#
# step: 121
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  7
#
# step: 122
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  3
#
# step: 123
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  -9
#
# step: 124
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  -7
#
# step: 125
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  16
#
# step: 126
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  20
#
# step: 127
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -5
#
# step: 128
#
# the action arm chosen is 5
#
# Arm pulled is 5
#
# the reward got is  19
#
# step: 129
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  25
#
# step: 130
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  9
#
# step: 131
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  0
#
# step: 132
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  2
#
# step: 133
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  6
#
# step: 134
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  21
#
# step: 135
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  15
#
# step: 136
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  -10
#
# step: 137
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  25
#
# step: 138
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  4
#
# step: 139
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  14
#
# step: 140
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  11
#
# step: 141
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  -8
#
# step: 142
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  -10
#
# step: 143
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  -6
#
# step: 144
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -2
#
# step: 145
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  -1
#
# step: 146
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  11
#
# step: 147
#
# the action arm chosen is 5
#
# Arm pulled is 5
#
# the reward got is  9
#
# step: 148
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  14
#
# step: 149
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  2
#
# step: 150
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  -5
#
# step: 151
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  21
#
# step: 152
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  22
#
# step: 153
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  -6
#
# step: 154
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  6
#
# step: 155
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  -1
#
# step: 156
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -8
#
# step: 157
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  3
#
# step: 158
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -3
#
# step: 159
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  4
#
# step: 160
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  17
#
# step: 161
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  19
#
# step: 162
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -5
#
# step: 163
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -7
#
# step: 164
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  -5
#
# step: 165
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  0
#
# step: 166
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  -1
#
# step: 167
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  3
#
# step: 168
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  12
#
# step: 169
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  -2
#
# step: 170
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  6
#
# step: 171
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -8
#
# step: 172
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  3
#
# step: 173
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  20
#
# step: 174
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  9
#
# step: 175
#
# the action arm chosen is 5
#
# Arm pulled is 5
#
# the reward got is  -7
#
# step: 176
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  0
#
# step: 177
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  7
#
# step: 178
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  25
#
# step: 179
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  4
#
# step: 180
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  11
#
# step: 181
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  13
#
# step: 182
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  -7
#
# step: 183
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  2
#
# step: 184
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  3
#
# step: 185
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  20
#
# step: 186
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  24
#
# step: 187
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  19
#
# step: 188
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  7
#
# step: 189
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  11
#
# step: 190
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  19
#
# step: 191
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  14
#
# step: 192
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  19
#
# step: 193
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  16
#
# step: 194
#
# the action arm chosen is 5
#
# Arm pulled is 5
#
# the reward got is  -4
#
# step: 195
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  -3
#
# step: 196
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  11
#
# step: 197
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  21
#
# step: 198
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  -10
#
# step: 199
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  13
#
# step: 200
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  11
#
# step: 201
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  -9
#
# step: 202
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  22
#
# step: 203
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  -5
#
# step: 204
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  23
#
# step: 205
#
# the action arm chosen is 5
#
# Arm pulled is 5
#
# the reward got is  -4
#
# step: 206
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  11
#
# step: 207
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  -1
#
# step: 208
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  -10
#
# step: 209
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  16
#
# step: 210
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  20
#
# step: 211
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  25
#
# step: 212
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  17
#
# step: 213
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  24
#
# step: 214
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  10
#
# step: 215
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  12
#
# step: 216
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  21
#
# step: 217
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  5
#
# step: 218
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  6
#
# step: 219
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  0
#
# step: 220
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  13
#
# step: 221
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  25
#
# step: 222
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  5
#
# step: 223
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  21
#
# step: 224
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  14
#
# step: 225
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  -8
#
# step: 226
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  14
#
# step: 227
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  25
#
# step: 228
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  -9
#
# step: 229
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  24
#
# step: 230
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  25
#
# step: 231
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  -10
#
# step: 232
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  16
#
# step: 233
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  17
#
# step: 234
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  14
#
# step: 235
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  1
#
# step: 236
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  20
#
# step: 237
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  16
#
# step: 238
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  -4
#
# step: 239
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  25
#
# step: 240
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  -8
#
# step: 241
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  13
#
# step: 242
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  -9
#
# step: 243
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  12
#
# step: 244
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  6
#
# step: 245
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  6
#
# step: 246
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  5
#
# step: 247
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  23
#
# step: 248
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  -4
#
# step: 249
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  -4
#
# step: 250
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  0
#
# step: 251
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  0
#
# step: 252
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  23
#
# step: 253
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  17
#
# step: 254
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  16
#
# step: 255
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  13
#
# step: 256
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  -10
#
# step: 257
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  25
#
# step: 258
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -6
#
# step: 259
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  22
#
# step: 260
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  19
#
# step: 261
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  23
#
# step: 262
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  23
#
# step: 263
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  24
#
# step: 264
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  8
#
# step: 265
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  22
#
# step: 266
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  11
#
# step: 267
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  15
#
# step: 268
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  20
#
# step: 269
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  14
#
# step: 270
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  1
#
# step: 271
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  9
#
# step: 272
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  6
#
# step: 273
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  2
#
# step: 274
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  -9
#
# step: 275
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  2
#
# step: 276
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  14
#
# step: 277
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  1
#
# step: 278
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  -5
#
# step: 279
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  -1
#
# step: 280
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  23
#
# step: 281
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  21
#
# step: 282
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  -6
#
# step: 283
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  7
#
# step: 284
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  -10
#
# step: 285
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  23
#
# step: 286
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  -8
#
# step: 287
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  23
#
# step: 288
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  8
#
# step: 289
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  25
#
# step: 290
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  12
#
# step: 291
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  15
#
# step: 292
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  -5
#
# step: 293
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  24
#
# step: 294
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  1
#
# step: 295
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  13
#
# step: 296
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  19
#
# step: 297
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  17
#
# step: 298
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  6
#
# step: 299
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  25
#
# step: 300
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  -2
#
# step: 301
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  17
#
# step: 302
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -3
#
# step: 303
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  -5
#
# step: 304
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  1
#
# step: 305
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  8
#
# step: 306
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  21
#
# step: 307
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  5
#
# step: 308
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  13
#
# step: 309
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  10
#
# step: 310
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  5
#
# step: 311
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  4
#
# step: 312
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  21
#
# step: 313
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  -7
#
# step: 314
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  17
#
# step: 315
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  -2
#
# step: 316
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  -6
#
# step: 317
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  2
#
# step: 318
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  -3
#
# step: 319
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  24
#
# step: 320
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  13
#
# step: 321
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  -9
#
# step: 322
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  22
#
# step: 323
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  20
#
# step: 324
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  14
#
# step: 325
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  7
#
# step: 326
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  16
#
# step: 327
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  10
#
# step: 328
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  4
#
# step: 329
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  24
#
# step: 330
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  17
#
# step: 331
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  4
#
# step: 332
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  9
#
# step: 333
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  -8
#
# step: 334
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  -9
#
# step: 335
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  15
#
# step: 336
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  -1
#
# step: 337
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  21
#
# step: 338
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  6
#
# step: 339
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  -3
#
# step: 340
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  12
#
# step: 341
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  17
#
# step: 342
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  0
#
# step: 343
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  14
#
# step: 344
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  18
#
# step: 345
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  -4
#
# step: 346
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  13
#
# step: 347
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  21
#
# step: 348
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  0
#
# step: 349
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  -6
#
# step: 350
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  24
#
# step: 351
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  12
#
# step: 352
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  6
#
# step: 353
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  -3
#
# step: 354
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  13
#
# step: 355
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -9
#
# step: 356
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  25
#
# step: 357
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  23
#
# step: 358
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  -9
#
# step: 359
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  16
#
# step: 360
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  -7
#
# step: 361
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  14
#
# step: 362
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  4
#
# step: 363
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  10
#
# step: 364
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  -4
#
# step: 365
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  1
#
# step: 366
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  6
#
# step: 367
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  24
#
# step: 368
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  -6
#
# step: 369
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  24
#
# step: 370
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  -9
#
# step: 371
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  17
#
# step: 372
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  10
#
# step: 373
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  21
#
# step: 374
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  16
#
# step: 375
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  3
#
# step: 376
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  9
#
# step: 377
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  23
#
# step: 378
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  3
#
# step: 379
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  7
#
# step: 380
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  23
#
# step: 381
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  22
#
# step: 382
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  10
#
# step: 383
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  5
#
# step: 384
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  4
#
# step: 385
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  -5
#
# step: 386
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  1
#
# step: 387
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  20
#
# step: 388
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  -1
#
# step: 389
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  3
#
# step: 390
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  22
#
# step: 391
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  -1
#
# step: 392
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  -7
#
# step: 393
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  25
#
# step: 394
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  6
#
# step: 395
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  21
#
# step: 396
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  22
#
# step: 397
#
# the action arm chosen is 5
#
# Arm pulled is 5
#
# the reward got is  25
#
# step: 398
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  -4
#
# step: 399
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  17
#
# step: 400
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  11
#
# step: 401
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  -3
#
# step: 402
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  18
#
# step: 403
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  -6
#
# step: 404
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  -7
#
# step: 405
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  -10
#
# step: 406
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  -3
#
# step: 407
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  21
#
# step: 408
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  2
#
# step: 409
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  -1
#
# step: 410
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  20
#
# step: 411
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  23
#
# step: 412
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  22
#
# step: 413
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  24
#
# step: 414
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  1
#
# step: 415
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  9
#
# step: 416
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  5
#
# step: 417
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  -1
#
# step: 418
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  9
#
# step: 419
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  -7
#
# step: 420
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  2
#
# step: 421
#
# the action arm chosen is 5
#
# Arm pulled is 5
#
# the reward got is  8
#
# step: 422
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  6
#
# step: 423
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  12
#
# step: 424
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  18
#
# step: 425
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  6
#
# step: 426
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  19
#
# step: 427
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  9
#
# step: 428
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  3
#
# step: 429
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  13
#
# step: 430
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  -2
#
# step: 431
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  19
#
# step: 432
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -8
#
# step: 433
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  -10
#
# step: 434
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  23
#
# step: 435
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  -4
#
# step: 436
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  9
#
# step: 437
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  -6
#
# step: 438
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  22
#
# step: 439
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  10
#
# step: 440
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  16
#
# step: 441
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  -5
#
# step: 442
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  17
#
# step: 443
#
# the action arm chosen is 5
#
# Arm pulled is 5
#
# the reward got is  -8
#
# step: 444
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  19
#
# step: 445
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  8
#
# step: 446
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  16
#
# step: 447
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  16
#
# step: 448
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  6
#
# step: 449
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  -1
#
# step: 450
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  13
#
# step: 451
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  -9
#
# step: 452
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -4
#
# step: 453
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  22
#
# step: 454
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  -4
#
# step: 455
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  8
#
# step: 456
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -9
#
# step: 457
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  9
#
# step: 458
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  17
#
# step: 459
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  13
#
# step: 460
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  25
#
# step: 461
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  18
#
# step: 462
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  -9
#
# step: 463
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  2
#
# step: 464
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  6
#
# step: 465
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  24
#
# step: 466
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  -10
#
# step: 467
#
# the action arm chosen is 5
#
# Arm pulled is 5
#
# the reward got is  -10
#
# step: 468
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -10
#
# step: 469
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  6
#
# step: 470
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  -8
#
# step: 471
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  15
#
# step: 472
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  17
#
# step: 473
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  19
#
# step: 474
#
# the action arm chosen is 5
#
# Arm pulled is 5
#
# the reward got is  24
#
# step: 475
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  4
#
# step: 476
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  21
#
# step: 477
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  2
#
# step: 478
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  4
#
# step: 479
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  2
#
# step: 480
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  25
#
# step: 481
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  -1
#
# step: 482
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  19
#
# step: 483
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -9
#
# step: 484
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  -8
#
# step: 485
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  11
#
# step: 486
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  -9
#
# step: 487
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  -8
#
# step: 488
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  21
#
# step: 489
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  4
#
# step: 490
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  -1
#
# step: 491
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  -8
#
# step: 492
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  11
#
# step: 493
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  5
#
# step: 494
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  22
#
# step: 495
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  16
#
# step: 496
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  -2
#
# step: 497
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  1
#
# step: 498
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  9
#
# step: 499
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  9
#
# step: 500
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  19
#
# step: 501
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  7
#
# step: 502
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  -6
#
# step: 503
#
# the action arm chosen is 5
#
# Arm pulled is 5
#
# the reward got is  9
#
# step: 504
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  6
#
# step: 505
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  2
#
# step: 506
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  17
#
# step: 507
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  19
#
# step: 508
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  -1
#
# step: 509
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  -5
#
# step: 510
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  1
#
# step: 511
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  -10
#
# step: 512
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  14
#
# step: 513
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  -8
#
# step: 514
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  -6
#
# step: 515
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  3
#
# step: 516
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  -5
#
# step: 517
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  0
#
# step: 518
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  12
#
# step: 519
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  20
#
# step: 520
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  -10
#
# step: 521
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  10
#
# step: 522
#
# the action arm chosen is 5
#
# Arm pulled is 5
#
# the reward got is  1
#
# step: 523
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  -2
#
# step: 524
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  -1
#
# step: 525
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  25
#
# step: 526
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  24
#
# step: 527
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  21
#
# step: 528
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  -6
#
# step: 529
#
# the action arm chosen is 5
#
# Arm pulled is 5
#
# the reward got is  22
#
# step: 530
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  6
#
# step: 531
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  18
#
# step: 532
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  25
#
# step: 533
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  -10
#
# step: 534
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  -7
#
# step: 535
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  23
#
# step: 536
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  5
#
# step: 537
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  5
#
# step: 538
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  11
#
# step: 539
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  -9
#
# step: 540
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  24
#
# step: 541
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  -4
#
# step: 542
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  8
#
# step: 543
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  3
#
# step: 544
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  10
#
# step: 545
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  -9
#
# step: 546
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  13
#
# step: 547
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  14
#
# step: 548
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  23
#
# step: 549
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  13
#
# step: 550
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  -8
#
# step: 551
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  1
#
# step: 552
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  -3
#
# step: 553
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  24
#
# step: 554
#
# the action arm chosen is 9
#
# Arm pulled is 9
#
# the reward got is  8
#
# step: 555
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  21
#
# step: 556
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  7
#
# step: 557
#
# the action arm chosen is 2
#
# Arm pulled is 2
#
# the reward got is  1
#
# step: 558
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  22
#
# step: 559
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  3
#
# step: 560
#
# the action arm chosen is 12
#
# Arm pulled is 12
#
# the reward got is  -6
#
# step: 561
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  6
#
# step: 562
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  17
#
# step: 563
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  21
#
# step: 564
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  13
#
# step: 565
#
# the action arm chosen is 1
#
# Arm pulled is 1
#
# the reward got is  7
#
# step: 566
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  7
#
# step: 567
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  5
#
# step: 568
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  22
#
# step: 569
#
# the action arm chosen is 7
#
# Arm pulled is 7
#
# the reward got is  9
#
# step: 570
#
# the action arm chosen is 8
#
# Arm pulled is 8
#
# the reward got is  -3
#
# step: 571
#
# the action arm chosen is 5
#
# Arm pulled is 5
#
# the reward got is  14
#
# step: 572
#
# the action arm chosen is 10
#
# Arm pulled is 10
#
# the reward got is  -2
#
# step: 573
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  -4
#
# step: 574
#
# the action arm chosen is 6
#
# Arm pulled is 6
#
# the reward got is  8
#
# step: 575
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  -5
#
# step: 576
#
# the action arm chosen is 4
#
# Arm pulled is 4
#
# the reward got is  -1
#
# step: 577
#
# the action arm chosen is 11
#
# Arm pulled is 11
#
# the reward got is  24
#
# step: 578
#
# the action arm chosen is 3
#
# ...
#
# Arm pulled is 3
#
# the reward got is  8
#
# step: 4811
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -1
#
# step: 4812
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -2
#
# step: 4813
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  0
#
# step: 4814
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  20
#
# step: 4815
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -9
#
# step: 4816
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  13
#
# step: 4817
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -6
#
# step: 4818
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  19
#
# step: 4819
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  24
#
# step: 4820
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  6
#
# step: 4821
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  20
#
# step: 4822
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -9
#
# step: 4823
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  5
#
# step: 4824
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  10
#
# step: 4825
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  19
#
# step: 4826
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -10
#
# step: 4827
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  3
#
# step: 4828
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  5
#
# step: 4829
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -2
#
# step: 4830
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -3
#
# step: 4831
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -2
#
# step: 4832
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  23
#
# step: 4833
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  22
#
# step: 4834
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  11
#
# step: 4835
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  19
#
# step: 4836
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -4
#
# step: 4837
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  7
#
# step: 4838
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  10
#
# step: 4839
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -6
#
# step: 4840
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -4
#
# step: 4841
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  1
#
# step: 4842
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  6
#
# step: 4843
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  13
#
# step: 4844
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  8
#
# step: 4845
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  5
#
# step: 4846
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  14
#
# step: 4847
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  16
#
# step: 4848
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -4
#
# step: 4849
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -3
#
# step: 4850
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  4
#
# step: 4851
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  5
#
# step: 4852
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -3
#
# step: 4853
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  25
#
# step: 4854
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  21
#
# step: 4855
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  6
#
# step: 4856
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  25
#
# step: 4857
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  11
#
# step: 4858
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  21
#
# step: 4859
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  0
#
# step: 4860
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -5
#
# step: 4861
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  11
#
# step: 4862
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  3
#
# step: 4863
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  17
#
# step: 4864
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  1
#
# step: 4865
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  16
#
# step: 4866
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -10
#
# step: 4867
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -1
#
# step: 4868
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  22
#
# step: 4869
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  5
#
# step: 4870
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -5
#
# step: 4871
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  14
#
# step: 4872
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  9
#
# step: 4873
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  25
#
# step: 4874
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  12
#
# step: 4875
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  5
#
# step: 4876
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -10
#
# step: 4877
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  19
#
# step: 4878
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  16
#
# step: 4879
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -9
#
# step: 4880
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  10
#
# step: 4881
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -2
#
# step: 4882
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  13
#
# step: 4883
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -4
#
# step: 4884
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  19
#
# step: 4885
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -9
#
# step: 4886
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  1
#
# step: 4887
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  2
#
# step: 4888
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -8
#
# step: 4889
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  7
#
# step: 4890
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -5
#
# step: 4891
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  16
#
# step: 4892
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  4
#
# step: 4893
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  4
#
# step: 4894
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  8
#
# step: 4895
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  9
#
# step: 4896
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  9
#
# step: 4897
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  7
#
# step: 4898
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  23
#
# step: 4899
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  24
#
# step: 4900
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -10
#
# step: 4901
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  1
#
# step: 4902
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -6
#
# step: 4903
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  16
#
# step: 4904
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  9
#
# step: 4905
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  8
#
# step: 4906
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  4
#
# step: 4907
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -5
#
# step: 4908
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -2
#
# step: 4909
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  25
#
# step: 4910
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  12
#
# step: 4911
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -1
#
# step: 4912
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -10
#
# step: 4913
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  0
#
# step: 4914
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  9
#
# step: 4915
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  17
#
# step: 4916
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  11
#
# step: 4917
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  9
#
# step: 4918
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  5
#
# step: 4919
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -9
#
# step: 4920
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  14
#
# step: 4921
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  16
#
# step: 4922
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -8
#
# step: 4923
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  12
#
# step: 4924
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  21
#
# step: 4925
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  6
#
# step: 4926
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  9
#
# step: 4927
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  19
#
# step: 4928
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  17
#
# step: 4929
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  12
#
# step: 4930
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  8
#
# step: 4931
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  14
#
# step: 4932
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  13
#
# step: 4933
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -10
#
# step: 4934
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  17
#
# step: 4935
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  18
#
# step: 4936
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  24
#
# step: 4937
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  6
#
# step: 4938
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  0
#
# step: 4939
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -4
#
# step: 4940
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  15
#
# step: 4941
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  12
#
# step: 4942
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  7
#
# step: 4943
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  18
#
# step: 4944
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  23
#
# step: 4945
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -3
#
# step: 4946
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  10
#
# step: 4947
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  10
#
# step: 4948
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  25
#
# step: 4949
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  6
#
# step: 4950
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  5
#
# step: 4951
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  4
#
# step: 4952
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  4
#
# step: 4953
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  6
#
# step: 4954
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -10
#
# step: 4955
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  2
#
# step: 4956
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -1
#
# step: 4957
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  22
#
# step: 4958
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  15
#
# step: 4959
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  1
#
# step: 4960
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  8
#
# step: 4961
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  4
#
# step: 4962
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -6
#
# step: 4963
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -9
#
# step: 4964
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  3
#
# step: 4965
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  18
#
# step: 4966
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -10
#
# step: 4967
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  2
#
# step: 4968
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  21
#
# step: 4969
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  23
#
# step: 4970
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  3
#
# step: 4971
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  4
#
# step: 4972
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -5
#
# step: 4973
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  18
#
# step: 4974
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  8
#
# step: 4975
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -10
#
# step: 4976
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  10
#
# step: 4977
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  7
#
# step: 4978
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  16
#
# step: 4979
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  17
#
# step: 4980
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -3
#
# step: 4981
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  20
#
# step: 4982
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  1
#
# step: 4983
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -5
#
# step: 4984
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  15
#
# step: 4985
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  5
#
# step: 4986
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  19
#
# step: 4987
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  8
#
# step: 4988
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  7
#
# step: 4989
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  13
#
# step: 4990
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  9
#
# step: 4991
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -4
#
# step: 4992
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -4
#
# step: 4993
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  5
#
# step: 4994
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  3
#
# step: 4995
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  1
#
# step: 4996
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  18
#
# step: 4997
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  4
#
# step: 4998
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -3
#
# step: 4999
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  -2
#
# step: 5000
#
# the action arm chosen is 3
#
# Arm pulled is 3
#
# the reward got is  17
#
# UCB policy for 5000 steps done

# %% [markdown]
# ### printing the rewards

# %%
print(f"the total cumulative reward for epsilon greedy policy is: {epsilon_reward} \n")
print(f"the total cumulative reward for UCB policy is: {ucb_reward} \n")
# Out:
# the total cumulative reward for epsilon greedy policy is: 37875
#
# the total cumulative reward for UCB policy is: 36680

# %% [markdown]
# ### Comparing the rewards

# %% [raw]
# the reward obtained for the UCB policy is higher compared to that of the epsilon greedy reward on running for 5000 steps
# since the reward generated for each action is not predifined based on any historical dataset and is randomly generated we cant
# completely rely on this evaluation,but since ucb gives general chances to all the actions it is more rewarding and a
# better approch for the given problem
